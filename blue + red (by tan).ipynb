# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df_b = pd.read_csv('blue_info.csv')

# %%
df_r = pd.read_csv('red_info.csv')

# %%
df_f = pd.read_csv('fighters.csv')

# %%
# BLUE FIGHTERS DATAFRAME
df_b.sample()

# %%
# RED FIGHTERS DATAFRAME
df_r.sample()

# %%
# REPLACE CATEGORICAL VALUES WITH NUMERICAL VALUES FOR CORR. CAL. PURPOSE 
blue_wins = {"Red": -1, "Blue": 1, "Draw" : 0}
df_b['Winner'] = df_b['Winner'].replace(blue_wins)

# %%
# TEST
df_b['Winner'].sample()

# %%
red_wins = {"Red": 1, "Blue": -1, "Draw" : 0}
df_r['Winner'] = df_r['Winner'].replace(red_wins)

# %%
# TEST
df_r['Winner'].sample()

# %%
b_info = df_b

# %%
b_info.to_csv('b_info.csv')

# %%
r_info = df_r

# %%
r_info.to_csv('r_info.csv')

# %%
# INSIGHTS // WEIGHT CLASS (BLUE)
sns.countplot(data = df_b ,x = 'weight_class', hue = 'Winner')

# %%
# INSIGHTS // WEIGHT CLASS (RED)
sns.countplot(data = df_r ,x = 'weight_class', hue = 'Winner')

# %%
sns.countplot(data = df_r ,x = 'R_age', hue = 'Winner')

# %%
set_r = set(df_r['R_fighter'])
set_b = set(df_b['B_fighter'])
from itertools import chain
unique_names = pd.Series(np.array((set(chain(set_r,set_b)))))
print(type(unique_names))
unique_names

# %%
df_bdropped = df_b

# %%
b_unique_names = df_bdropped.drop_duplicates(subset = 'B_fighter' , keep = "first")
b_unique_names['B_fighter'].value_counts()

# %%
df_rdropped = df_r

# %%
b_unique_names.head(3)

# %%
r_unique_names = df_rdropped.drop_duplicates(subset = 'R_fighter' , keep = "first")
r_unique_names['R_fighter'].value_counts()

# %%
r_unique_names.head(3)

# %%
fighter_merged = pd.merge(r_unique_names, df_f, left_on = "R_fighter", right_on = "fighter_name", how = "right")

# %%
fighter_merged.head()

# %%
fighter_merged = pd.merge(fighter_merged, b_unique_names, left_on = "R_fighter", right_on = "B_fighter", how = "left")

# %%
fighter_merged.head()

# %%
b_info.drop(b_info.columns[0], axis=1)

# %%
r_info = r_info.drop(r_info.columns[0], axis=1)

# %%
b_info.to_csv('b_info.csv')

# %%
r_info.to_csv('r_info.csv')

# %%
r_info.head(5)

# %%
b_info = b_info.dropna(subset=['B_age'])

# %%
b_info.sample()
# Out:
#         B_fighter    Referee        date            location  Winner  \
# 636  Joby Sanchez  Herb Dean  2018-02-18  Austin, Texas, USA      -1
#
#      title_bout weight_class  no_of_rounds  B_current_lose_streak  \
# 636       False    Flyweight             3                    1.0
#
#      B_current_win_streak  ...  B_win_by_Decision_Unanimous  B_win_by_KO/TKO  \
# 636                   0.0  ...                          0.0              0.0
#
#      B_win_by_Submission  B_win_by_TKO_Doctor_Stoppage  B_wins  B_Stance  \
# 636                  0.0                           0.0     1.0  Orthodox
#
#      B_Height_cms  B_Reach_cms  B_Weight_lbs  B_age
# 636        167.64       172.72         135.0   26.0
#
# [1 rows x 76 columns]

# %%
b_info = b_info.drop(b_info.columns[0], axis=1)

# %%
b_info[b_info['B_age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [B_fighter, Referee, date, location, Winner, title_bout, weight_class, no_of_rounds, B_current_lose_streak, B_current_win_streak, B_draw, B_avg_BODY_att, B_avg_BODY_landed, B_avg_CLINCH_att, B_avg_CLINCH_landed, B_avg_DISTANCE_att, B_avg_DISTANCE_landed, B_avg_GROUND_att, B_avg_GROUND_landed, B_avg_HEAD_att, B_avg_HEAD_landed, B_avg_KD, B_avg_LEG_att, B_avg_LEG_landed, B_avg_PASS, B_avg_REV, B_avg_SIG_STR_att, B_avg_SIG_STR_landed, B_avg_SIG_STR_pct, B_avg_SUB_ATT, B_avg_TD_att, B_avg_TD_landed, B_avg_TD_pct, B_avg_TOTAL_STR_att, B_avg_TOTAL_STR_landed, B_longest_win_streak, B_losses, B_avg_opp_BODY_att, B_avg_opp_BODY_landed, B_avg_opp_CLINCH_att, B_avg_opp_CLINCH_landed, B_avg_opp_DISTANCE_att, B_avg_opp_DISTANCE_landed, B_avg_opp_GROUND_att, B_avg_opp_GROUND_landed, B_avg_opp_HEAD_att, B_avg_opp_HEAD_landed, B_avg_opp_KD, B_avg_opp_LEG_att, B_avg_opp_LEG_landed, B_avg_opp_PASS, B_avg_opp_REV, B_avg_opp_SIG_STR_att, B_avg_opp_SIG_STR_landed, B_avg_opp_SIG_STR_pct, B_avg_opp_SUB_ATT, B_avg_opp_TD_att, B_avg_opp_TD_landed, B_avg_opp_TD_pct, B_avg_opp_TOTAL_STR_att, B_avg_opp_TOTAL_STR_landed, B_total_rounds_fought, B_total_time_fought(seconds), B_total_title_bouts, B_win_by_Decision_Majority, B_win_by_Decision_Split, B_win_by_Decision_Unanimous, B_win_by_KO/TKO, B_win_by_Submission, B_win_by_TKO_Doctor_Stoppage, B_wins, B_Stance, B_Height_cms, B_Reach_cms, B_Weight_lbs, B_age]
# Index: []
#
# [0 rows x 76 columns]

# %%
r_info = r_info.dropna(subset=['R_age'])

# %%
r_info[r_info['R_age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, R_fighter, Referee, date, location, Winner, title_bout, weight_class, no_of_rounds, R_current_lose_streak, R_current_win_streak, R_draw, R_avg_BODY_att, R_avg_BODY_landed, R_avg_CLINCH_att, R_avg_CLINCH_landed, R_avg_DISTANCE_att, R_avg_DISTANCE_landed, R_avg_GROUND_att, R_avg_GROUND_landed, R_avg_HEAD_att, R_avg_HEAD_landed, R_avg_KD, R_avg_LEG_att, R_avg_LEG_landed, R_avg_PASS, R_avg_REV, R_avg_SIG_STR_att, R_avg_SIG_STR_landed, R_avg_SIG_STR_pct, R_avg_SUB_ATT, R_avg_TD_att, R_avg_TD_landed, R_avg_TD_pct, R_avg_TOTAL_STR_att, R_avg_TOTAL_STR_landed, R_longest_win_streak, R_losses, R_avg_opp_BODY_att, R_avg_opp_BODY_landed, R_avg_opp_CLINCH_att, R_avg_opp_CLINCH_landed, R_avg_opp_DISTANCE_att, R_avg_opp_DISTANCE_landed, R_avg_opp_GROUND_att, R_avg_opp_GROUND_landed, R_avg_opp_HEAD_att, R_avg_opp_HEAD_landed, R_avg_opp_KD, R_avg_opp_LEG_att, R_avg_opp_LEG_landed, R_avg_opp_PASS, R_avg_opp_REV, R_avg_opp_SIG_STR_att, R_avg_opp_SIG_STR_landed, R_avg_opp_SIG_STR_pct, R_avg_opp_SUB_ATT, R_avg_opp_TD_att, R_avg_opp_TD_landed, R_avg_opp_TD_pct, R_avg_opp_TOTAL_STR_att, R_avg_opp_TOTAL_STR_landed, R_total_rounds_fought, R_total_time_fought(seconds), R_total_title_bouts, R_win_by_Decision_Majority, R_win_by_Decision_Split, R_win_by_Decision_Unanimous, R_win_by_KO/TKO, R_win_by_Submission, R_win_by_TKO_Doctor_Stoppage, R_wins, R_Stance, R_Height_cms, R_Reach_cms, R_Weight_lbs, R_age]
# Index: []
#
# [0 rows x 77 columns]

# %%
r_info
